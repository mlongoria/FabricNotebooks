# %%
#%pip install semantic-link-labs
# Out:
# StatementMeta(, 1e03b111-684a-48c1-b6b7-cde69d63c0f0, 5, Finished, Available, Finished)

# %%
# Imports
import sempy_labs as labs
from sempy_labs import report
from sempy_labs import theme

import pandas as pd
# Out:
# StatementMeta(, e9a6d2ef-d69e-4a88-b81a-f6bb5fb240c5, 6, Finished, Available, Finished)

# %%
var_rpt = '44fda655-5516-4a82-b3fc-549e55ae65c8'
var_ws = '185136d7-debf-4d5d-a875-58b900849e4a'
# Out:
# StatementMeta(, e9a6d2ef-d69e-4a88-b81a-f6bb5fb240c5, 7, Finished, Available, Finished)

# %%
var_rptw = labs.report.ReportWrapper(report=var_rpt, workspace=var_ws,readonly=False)

from sempy_labs.report import connect_report

report = var_rpt  # Name or ID of the report
workspace = var_ws # Name or ID of the workspace in which the report resides
theme_type = 'customTheme' # Set this to 'customTheme' to get the custom theme. None defaults to the base theme

with connect_report(report=report, workspace=workspace) as rpt:
    theme = rpt.get_theme(theme_type=theme_type)
theme
# Out:
# StatementMeta(, e9a6d2ef-d69e-4a88-b81a-f6bb5fb240c5, 8, Finished, Available, Finished)
# {'name': 'ProcureSQL',
#  'textClasses': {'callout': {'fontFace': "'Segoe UI', wf_segoe-ui_normal, helvetica, arial, sans-serif"},
#   'title': {'color': '#333333',
#    'fontFace': "'Segoe UI Semibold', wf_segoe-ui_semibold, helvetica, arial, sans-serif"}},
#  'dataColors': ['#158AE3',
#   '#5F62B3',
#   '#7E7E85',
#   '#895D99',
#   '#399E99',
#   '#CCBE00',
#   '#ACBDD2',
#   '#E6E6E6',
#   '#3599B8',
#   '#DFBFBF',
#   '#4AC5BB',
#   '#5F6B6D',
#   '#FB8281',
#   '#F4D25A',
#   '#7F898A',
#   '#A4DDEE',
#   '#FDAB89',
#   '#B687AC',
#   '#28738A',
#   '#A78F8F',
#   '#168980',
#   '#293537',
#   '#BB4A4A',
#   '#B59525',
#   '#475052',
#   '#6A9FB0',
#   '#BD7150',
#   '#7B4F71',
#   '#1B4D5C',
#   '#706060',
#   '#0F5C55',
#   '#1C2325',
#   '#7D3231',
#   '#796419',
#   '#303637',
#   '#476A75',
#   '#7E4B36',
#   '#52354C',
#   '#0D262E',
#   '#544848',
#   '#016AB8',
#   '#373D49',
# ...

# %%
from PIL import Image, ImageDraw

# Create a blank image
img = Image.new('RGB', (200, 200), 'white')
draw = ImageDraw.Draw(img)
draw.rectangle([50, 50, 250, 150], fill='#158AE3', outline='white')

img2 = Image.new('RGB', (200, 200), 'white')
draw = ImageDraw.Draw(img2)
draw.rectangle([50, 50, 250, 150], fill='#5F62B3', outline='white')



img.show()
img2.show()
# Out:
# StatementMeta(, 1e03b111-684a-48c1-b6b7-cde69d63c0f0, 9, Finished, Available, Finished)
# <PIL.Image.Image image mode=RGB size=200x200>
# <PIL.Image.Image image mode=RGB size=200x200>

# %%
var_reportname = labs.resolve_report_name(var_rpt, workspace=var_ws)

labs.report.launch_report(report=var_reportname, workspace=var_ws)
# Out:
# StatementMeta(, 1e03b111-684a-48c1-b6b7-cde69d63c0f0, 10, Finished, Available, Finished)
# Report()
# StatementMeta(, 1e03b111-684a-48c1-b6b7-cde69d63c0f0, 11, Finished, Available, Finished)
# StatementMeta(, 1e03b111-684a-48c1-b6b7-cde69d63c0f0, 12, Finished, Available, Finished)
# StatementMeta(, 1e03b111-684a-48c1-b6b7-cde69d63c0f0, 13, Finished, Available, Finished)
# StatementMeta(, 1e03b111-684a-48c1-b6b7-cde69d63c0f0, 14, Finished, Available, Finished)
